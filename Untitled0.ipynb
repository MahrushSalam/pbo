# %% [markdown]
# <a href="https://colab.research.google.com/github/MahrushSalam/pbo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class lingkaran:
  def luas_lk():
    pi = 3.14
    r = 6
    L = pi * r * r
    print(L)
  def keliling_lk():
    pi = 3.14
    r = 6
    K = 2 * pi * r
    print(K)

# %%
lingkaran1 = lingkaran
lingkaran2 = lingkaran
lingkaran1.luas_lk()
lingkaran2.keliling_lk()
# Out:
# 113.03999999999999
# 37.68

# %%
class bk:
  def __init__(self, d1, d2):
    self.da = d1
    self.db = d2
  def luas(self):
      return self.da * self.db * 0.5

# %%
bk1 = bk(5, 10)
bk1.luas()
# Out:
# 25.0
